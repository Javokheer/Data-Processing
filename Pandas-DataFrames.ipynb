# %%
import pandas as pd

dataset = pd.read_csv(r'C:\Users\acer\OneDrive - SP JAIN SCHOOL OF GLOBAL MANAGEMENT\Computer programming\dataset\Admission_Predict.csv', index_col=0)
dataset
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
# ...               ...          ...                ...  ...   ...   ...
# 396               324          110                  3  3.5   3.5  9.04
# 397               325          107                  3  3.0   3.5  9.11
# 398               330          116                  4  5.0   4.5  9.45
# 399               312          103                  3  3.5   4.0  8.78
# 400               333          117                  4  5.0   4.0  9.66
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# ...

# %%
admit_chance = dataset['Chance of Admit '] > 0.7
admit_chance.head(10)
# Out:
# Serial No.
# 1      True
# 2      True
# 3      True
# 4      True
# 5     False
# 6      True
# 7      True
# 8     False
# 9     False
# 10    False
# Name: Chance of Admit , dtype: bool

# %%
dataset.where(admit_chance).shape
# Out:
# (400, 8)

# %%
dataset_nom = dataset.where(admit_chance).dropna().head()
dataset_nom.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1               337.0        118.0                4.0  4.5   4.5  9.65
# 2               324.0        107.0                4.0  4.0   4.5  8.87
# 3               316.0        104.0                3.0  3.0   3.5  8.00
# 4               322.0        110.0                3.0  3.5   2.5  8.67
# 6               330.0        115.0                5.0  4.5   3.0  9.34
#
#             Research  Chance of Admit
# Serial No.
# 1                1.0              0.92
# 2                1.0              0.76
# 3                1.0              0.72
# 4                1.0              0.80
# 6                1.0              0.90

# %%
(dataset['Chance of Admit '] > 0.7) & (dataset['Chance of Admit '] < 0.9)
# Out:
# Serial No.
# 1      False
# 2       True
# 3       True
# 4       True
# 5      False
#        ...
# 396     True
# 397     True
# 398    False
# 399    False
# 400    False
# Name: Chance of Admit , Length: 400, dtype: bool

# %%
(dataset['Chance of Admit '] > 0.7) & (dataset['Chance of Admit '] < 0.9)
# Out:
# Serial No.
# 1      False
# 2       True
# 3       True
# 4       True
# 5      False
#        ...
# 396     True
# 397     True
# 398    False
# 399    False
# 400    False
# Name: Chance of Admit , Length: 400, dtype: bool

# %% [markdown]
# ### Introducing compound condition w/out wrapping with parnethesis  leads to  error below the cell

# %%
dataset['Chance of Admit '] > 0.7 & dataset['Chance of Admit '] < 0.9
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\acer\miniconda3\envs\main\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     264         #  (xint or xbool) and (yint or bool)
# --> 265         result = op(x, y)
#     266     except TypeError:
#
# c:\users\acer\miniconda3\envs\main\lib\site-packages\pandas\core\ops\roperator.py in rand_(left, right)
#      51 def rand_(left, right):
# ---> 52     return operator.and_(right, left)
#      53
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ...

# %%
dataset['Chance of Admit '].gt(0.7) & dataset['Chance of Admit '].lt(0.9)
# Out:
# Serial No.
# 1      False
# 2       True
# 3       True
# 4       True
# 5      False
#        ...
# 396     True
# 397     True
# 398    False
# 399    False
# 400    False
# Name: Chance of Admit , Length: 400, dtype: bool

# %%
 dataset['Chance of Admit '].gt(0.7).lt(0.9)
# Out:
# Serial No.
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
#        ...
# 396    False
# 397    False
# 398    False
# 399     True
# 400    False
# Name: Chance of Admit , Length: 400, dtype: bool

# %%
# gt means > while lt <. Ampercent sign is used instead of 'and', while pipe is 
# used instead of or
mask = dataset['LOR '].gt(2.1) & dataset['Chance of Admit '].gt(0.7)

# %%
dataset.where(mask).dropna().shape
# Out:
# (231, 8)

# %%
dataset['LOR '].unique()
# Out:
# array([4.5, 3.5, 2.5, 3. , 4. , 1.5, 2. , 5. , 1. ])

# %% [markdown]
# # Indexing Dataframes

# %%
dataset.shape
# Out:
# (400, 8)

# %%
dataset.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# 2                  1              0.76
# 3                  1              0.72
# 4                  1              0.80
# 5                  0              0.65

# %%
dataset['Serial Number'] = dataset.index
dataset  = dataset['Research']
dataset
# Out:
# Serial No.
# 1      1
# 2      1
# 3      1
# 4      1
# 5      0
#       ..
# 396    1
# 397    1
# 398    1
# 399    0
# 400    1
# Name: Research, Length: 400, dtype: int64

# %%
dataset1 = pd.read_csv(r'C:\Users\acer\OneDrive - SP JAIN SCHOOL OF GLOBAL MANAGEMENT\Computer programming\dataset\census.csv', index_col=0)
dataset1.head()
# Out:
#         REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# SUMLEV
# 40           3         6      1       0  Alabama         Alabama
# 50           3         6      1       1  Alabama  Autauga County
# 50           3         6      1       3  Alabama  Baldwin County
# 50           3         6      1       5  Alabama  Barbour County
# 50           3         6      1       7  Alabama     Bibb County
#
#         CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# SUMLEV
# 40            4779736            4780127          4785161          4801108
# 50              54571              54571            54660            55253
# 50             182265             182265           183193           186659
# 50              27457              27457            27341            27226
# 50              22915              22919            22861            22733
#
#         ...  RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  \
# SUMLEV  ...
# ...

# %%
type(dataset1)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset1 = dataset1.set_index(['STNAME', 'CTYNAME'])
dataset1
# Out:
#                            REGION  DIVISION  STATE  COUNTY  CENSUS2010POP  \
# STNAME  CTYNAME
# Alabama Alabama                 3         6      1       0        4779736
#         Autauga County          3         6      1       1          54571
#         Baldwin County          3         6      1       3         182265
#         Barbour County          3         6      1       5          27457
#         Bibb County             3         6      1       7          22915
# ...                           ...       ...    ...     ...            ...
# Wyoming Sweetwater County       4         8     56      37          43806
#         Teton County            4         8     56      39          21294
#         Uinta County            4         8     56      41          21118
#         Washakie County         4         8     56      43           8533
#         Weston County           4         8     56      45           7208
#
# ...

# %%
dataset1.loc['Wyoming', 'Teton County']
# Out:
# <ipython-input-20-47207a39d462>:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   dataset1.loc['Wyoming', 'Teton County']
#                       REGION  DIVISION  STATE  COUNTY  CENSUS2010POP  \
# STNAME  CTYNAME
# Wyoming Teton County       4         8     56      39          21294
#
#                       ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# STNAME  CTYNAME
# Wyoming Teton County              21294            21297            21482
#
#                       POPESTIMATE2012  POPESTIMATE2013  ...  RDOMESTICMIG2011  \
# STNAME  CTYNAME                                         ...
# Wyoming Teton County            21697            22347  ...         -1.589565
#
#                       RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# STNAME  CTYNAME
# Wyoming Teton County          0.972695         19.525929         14.143021
#
#                       RDOMESTICMIG2015  RNETMIG2011  RNETMIG2012  RNETMIG2013  \
# STNAME  CTYNAME
# ...

# %%
# here below we are giving indexes as list of tuples
dataset1.loc[[('Wyoming', 'Weston County'),
             ('Michigan', 'Wayne County')]]
# Out:
#                         REGION  DIVISION  STATE  COUNTY  CENSUS2010POP  \
# STNAME   CTYNAME
# Wyoming  Weston County       4         8     56      45           7208
# Michigan Wayne County        2         3     26     163        1820584
#
#                         ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# STNAME   CTYNAME
# Wyoming  Weston County               7208             7181             7114
# Michigan Wayne County             1820641          1815199          1801273
#
#                         POPESTIMATE2012  POPESTIMATE2013  ...  \
# STNAME   CTYNAME                                          ...
# Wyoming  Weston County             7065             7160  ...
# Michigan Wayne County           1792514          1775713  ...
#
#                         RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  \
# STNAME   CTYNAME
# Wyoming  Weston County        -11.752361         -8.040059         12.372583
# ...

# %% [markdown]
# # Missing Values

# %%
dataset_class = pd.read_csv(r'C:\Users\acer\OneDrive - SP JAIN SCHOOL OF GLOBAL MANAGEMENT\Computer programming\dataset\class_grades.csv', index_col=0)
dataset_class.head()
# Out:
#         Assignment  Tutorial  Midterm  TakeHome  Final
# Prefix
# 5            57.14     34.09    64.38     51.48  52.50
# 8            95.05    105.49    67.50     99.07  68.33
# 8            83.70     83.17      NaN     63.15  48.89
# 7              NaN       NaN    49.38    105.93  80.56
# 8            91.32     93.64    95.00    107.41  73.89

# %%
dataset_class.isnull().sum()
# Out:
# Assignment    7
# Tutorial      3
# Midterm       3
# TakeHome      5
# Final         3
# dtype: int64

# %%
dataset_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 5 to 8
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Assignment  92 non-null     float64
#  1   Tutorial    96 non-null     float64
#  2   Midterm     96 non-null     float64
#  3   TakeHome    94 non-null     float64
#  4   Final       96 non-null     float64
# dtypes: float64(5)
# memory usage: 4.6 KB

# %%
df = dataset_class.isnull().sum()
df
# Out:
# Assignment    7
# Tutorial      3
# Midterm       3
# TakeHome      5
# Final         3
# dtype: int64

# %%
dataset_class.shape
# Out:
# (99, 5)

# %%
df = dataset_class.dropna()

# %%
df.head()
# Out:
#         Assignment  Tutorial  Midterm  TakeHome  Final
# Prefix
# 5            57.14     34.09    64.38     51.48  52.50
# 8            95.05    105.49    67.50     99.07  68.33
# 8            91.32     93.64    95.00    107.41  73.89
# 7            95.00     92.58    93.12     97.78  68.06
# 8            95.05    102.99    56.25     99.07  50.00

# %%
log_data = pd.read_csv(r'C:\Users\acer\OneDrive - SP JAIN SCHOOL OF GLOBAL MANAGEMENT\Computer programming\dataset\log.csv', index_col=0)
log_data
# Out:
#               user          video  playback position paused  volume
# time
# 1469974424  cheryl     intro.html                  5  False    10.0
# 1469974454  cheryl     intro.html                  6    NaN     NaN
# 1469974544  cheryl     intro.html                  9    NaN     NaN
# 1469974574  cheryl     intro.html                 10    NaN     NaN
# 1469977514     bob     intro.html                  1    NaN     NaN
# 1469977544     bob     intro.html                  1    NaN     NaN
# 1469977574     bob     intro.html                  1    NaN     NaN
# 1469977604     bob     intro.html                  1    NaN     NaN
# 1469974604  cheryl     intro.html                 11    NaN     NaN
# 1469974694  cheryl     intro.html                 14    NaN     NaN
# 1469974724  cheryl     intro.html                 15    NaN     NaN
# 1469974454     sue  advanced.html                 24    NaN     NaN
# 1469974524     sue  advanced.html                 25    NaN     NaN
# ...

# %%
log_data = log_data.fillna(method='ffill')

# %%
log_data.isnull().sum()
# Out:
# user                 0
# video                0
# playback position    0
# paused               0
# volume               0
# dtype: int64

# %%
df = pd.DataFrame({'A':[1, 1, 2, 3, 4],
                   'B':[3, 6, 3, 8, 9],
                   'C':['a', 'b', 'c', 'd', 'e']})

df
# Out:
#    A  B  C
# 0  1  3  a
# 1  1  6  b
# 2  2  3  c
# 3  3  8  d
# 4  4  9  e

# %%
# value to value approach
df.replace(1,100)
# Out:
#      A  B  C
# 0  100  3  a
# 1  100  6  b
# 2    2  3  c
# 3    3  8  d
# 4    4  9  e

# %%
# replacing with list
df.replace([1,3], [100, 300])
# Out:
#      A    B  C
# 0  100  300  a
# 1  100    6  b
# 2    2  300  c
# 3  300    8  d
# 4    4    9  e

# %%
log_data = pd.read_csv(r'C:\Users\acer\OneDrive - SP JAIN SCHOOL OF GLOBAL MANAGEMENT\Computer programming\dataset\log.csv', index_col=0)
log_data
# Out:
#               user          video  playback position paused  volume
# time
# 1469974424  cheryl     intro.html                  5  False    10.0
# 1469974454  cheryl     intro.html                  6    NaN     NaN
# 1469974544  cheryl     intro.html                  9    NaN     NaN
# 1469974574  cheryl     intro.html                 10    NaN     NaN
# 1469977514     bob     intro.html                  1    NaN     NaN
# 1469977544     bob     intro.html                  1    NaN     NaN
# 1469977574     bob     intro.html                  1    NaN     NaN
# 1469977604     bob     intro.html                  1    NaN     NaN
# 1469974604  cheryl     intro.html                 11    NaN     NaN
# 1469974694  cheryl     intro.html                 14    NaN     NaN
# 1469974724  cheryl     intro.html                 15    NaN     NaN
# 1469974454     sue  advanced.html                 24    NaN     NaN
# 1469974524     sue  advanced.html                 25    NaN     NaN
# ...

# %%
# to replace with regex we make a the first parametr to replace the regex pattern
# we wanna match, the second parameter the value we wanna to emit upon match, and 
# the third parameter 'regex=True'

# %%
# here below code finds all  pages end with'.html' in 'video' column and we want 
# to overwrite that with the keyword 'webpage'. 
log_data.replace(to_replace='.*html$', value='Webpage', regex=True)
# Out:
#               user    video  playback position paused  volume
# time
# 1469974424  cheryl  Webpage                  5  False    10.0
# 1469974454  cheryl  Webpage                  6    NaN     NaN
# 1469974544  cheryl  Webpage                  9    NaN     NaN
# 1469974574  cheryl  Webpage                 10    NaN     NaN
# 1469977514     bob  Webpage                  1    NaN     NaN
# 1469977544     bob  Webpage                  1    NaN     NaN
# 1469977574     bob  Webpage                  1    NaN     NaN
# 1469977604     bob  Webpage                  1    NaN     NaN
# 1469974604  cheryl  Webpage                 11    NaN     NaN
# 1469974694  cheryl  Webpage                 14    NaN     NaN
# 1469974724  cheryl  Webpage                 15    NaN     NaN
# 1469974454     sue  Webpage                 24    NaN     NaN
# 1469974524     sue  Webpage                 25    NaN     NaN
# 1469974424     sue  Webpage                 23  False    10.0
# ...

# %% [markdown]
# # Manipulating DataFrame

# %%
president = pd.read_csv(r'C:\Users\acer\OneDrive - SP JAIN SCHOOL OF GLOBAL MANAGEMENT\Computer programming\dataset\presidents.csv', index_col=0)
president
# Out:
#                 President             Born       Age atstart of presidency  \
# #
# 1       George Washington  Feb 22, 1732[a]   57 years, 67 daysApr 30, 1789
# 2              John Adams  Oct 30, 1735[a]   61 years, 125 daysMar 4, 1797
# 3        Thomas Jefferson  Apr 13, 1743[a]   57 years, 325 daysMar 4, 1801
# 4           James Madison  Mar 16, 1751[a]   57 years, 353 daysMar 4, 1809
# 5            James Monroe     Apr 28, 1758   58 years, 310 daysMar 4, 1817
# 6       John Quincy Adams     Jul 11, 1767   57 years, 236 daysMar 4, 1825
# 7          Andrew Jackson     Mar 15, 1767   61 years, 354 daysMar 4, 1829
# 8        Martin Van Buren      Dec 5, 1782    54 years, 89 daysMar 4, 1837
# 9     William H. Harrison      Feb 9, 1773    68 years, 23 daysMar 4, 1841
# 10             John Tyler     Mar 29, 1790     51 years, 6 daysApr 4, 1841
# 11          James K. Polk      Nov 2, 1795   49 years, 122 daysMar 4, 1845
# ...

# %%
president.shape
# Out:
# (44, 7)

# %%
president['First'] = president['President']
president['First'] = president['First'].replace('[ ].*', '', regex=True)

# %%
president
# Out:
#                 President             Born       Age atstart of presidency  \
# #
# 1       George Washington  Feb 22, 1732[a]   57 years, 67 daysApr 30, 1789
# 2              John Adams  Oct 30, 1735[a]   61 years, 125 daysMar 4, 1797
# 3        Thomas Jefferson  Apr 13, 1743[a]   57 years, 325 daysMar 4, 1801
# 4           James Madison  Mar 16, 1751[a]   57 years, 353 daysMar 4, 1809
# 5            James Monroe     Apr 28, 1758   58 years, 310 daysMar 4, 1817
# 6       John Quincy Adams     Jul 11, 1767   57 years, 236 daysMar 4, 1825
# 7          Andrew Jackson     Mar 15, 1767   61 years, 354 daysMar 4, 1829
# 8        Martin Van Buren      Dec 5, 1782    54 years, 89 daysMar 4, 1837
# 9     William H. Harrison      Feb 9, 1773    68 years, 23 daysMar 4, 1841
# 10             John Tyler     Mar 29, 1790     51 years, 6 daysApr 4, 1841
# 11          James K. Polk      Nov 2, 1795   49 years, 122 daysMar 4, 1845
# ...

# %%
import pandas as pd
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj1 = pd.Series(sdata)
states = ['California', 'Ohio', 'Oregon', 'Texas']
obj2 = pd.Series(sdata, index=states)
obj3 = pd.isnull(obj2)
